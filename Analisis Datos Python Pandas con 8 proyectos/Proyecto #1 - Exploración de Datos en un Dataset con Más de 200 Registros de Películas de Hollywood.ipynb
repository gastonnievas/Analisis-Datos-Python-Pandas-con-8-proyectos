# %% [markdown]
# # Proyecto #1 - Exploración de Datos en un Dataset con Más de 200 Registros de Películas de Hollywood

# %% [markdown]
# ## 1. Diccionarios
#
# Usted acaba de lanzar un nuevo e-commerce llamado Pandas Clothes. Usted necesita un DataFrame que contenga informacion acerca de sus productos.Cree un DataFrame con un diccionario los siguientes datos:

# %% [markdown]
# ![Screenshot%20from%202020-05-27%2011-37-59.png](attachment:Screenshot%20from%202020-05-27%2011-37-59.png)

# %% [markdown]
# Nosotros hemos creado la informacion del `product id` en `df1`. Añade el codigo para crear las columnas `Product Name` y `Color` y sus datos asociados

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({
    'Product ID': [1, 2, 3, 4],
    'Product Name': ['t-shirt', 't-shirt', 'skirt', 'skirt'],
    'Color': ['blue', 'green', 'red', 'black']
})
print(df1)
# Out:
#    Product ID Product Name  Color
# 0           1      t-shirt   blue
# 1           2      t-shirt  green
# 2           3        skirt    red
# 3           4        skirt  black

# %% [markdown]
# ## 2. Listas
#
# Usted esta administrando una cadena de cafe. Usted necesita creat un DataFrame con la informacion acerca de los diferentes sedes. Use una lista para crear un DataFrame con los siguientes datos:

# %% [markdown]
# ![Screenshot%20from%202020-05-27%2011-39-07.png](attachment:Screenshot%20from%202020-05-27%2011-39-07.png)

# %%
df2 = pd.DataFrame([
    [1, 'San Diego', 100],
    [2, 'Los Angeles', 120],
    [3, 'San Francisco', 90],
    [4, 'Sacramento', 115]
    ],
    columns = ['Store ID', 'Location', 'Number of Employees'])

print(df2)
# Out:
#    Store ID       Location  Number of Employees
# 0         1      San Diego                  100
# 1         2    Los Angeles                  120
# 2         3  San Francisco                   90
# 3         4     Sacramento                  115

# %% [markdown]
# ## 3. CSVs
#
# Usted esta corriendo un tienda de cupcakes que usted hace en casa. Escriba los siguientes datos en un CSV en `cupcakes.csv`

# %% [markdown]
# ![Screenshot%20from%202020-05-27%2011-39-56.png](attachment:Screenshot%20from%202020-05-27%2011-39-56.png)

# %%
#Una forma
csv = """
name, cake_flavor,frosting_flavor,topping
Devil's Food,chocolate,chocolate,chocolate shavings
Birthday Cake,vanilla,vanilla,raunbow sprinkles
Carrot Cake,carrot,creame cheese,almonds
"""
#Otra forma: crear la forma anterior en el dataset y llamarla
df0 = pd.read_csv('datasets/cupcakes.csv')
print(df0)
# Out:
#             name cake_flavor frosting_flavor             topping
# 0   Devil's Food   chocolate       chocolate  chocolate shavings
# 1  Birthday Cake     vanilla         vanilla   raunbow sprinkles
# 2    Carrot Cake      carrot   creame cheese             almonds

# %% [markdown]
# ## 4. Movies
#
# Usted esta trabajando en un estudio de Hollywood y tratando de usar datos para predecir el proximo hit en taquilla. Cargue el archivo `imdb.csv` (trabajado previamente en clase) dentro de una variable llamada `df` y asi usted podra aprender sobre las peliculas mas populares en los ultimos 90 años.

# %%
df = pd.read_csv('datasets/imdb.csv')
df
# Out:
#       id                                       name   genre  year imdb_rating
# 0      1                                     Avatar  action  2009         7.9
# 1      2                             Jurassic World  action  2015         7.3
# 2      3                               The Avengers  action  2012         8.1
# 3      4                            The Dark Knight  action  2008         9.0
# 4      5  Star Wars: Episode I - The Phantom Menace  action  1999         6.6
# ..   ...                                        ...     ...   ...         ...
# 215  216                                   Hannibal   drama  2001         6.7
# 216  217                        Catch Me If You Can   drama  2002         8.0
# 217  218                                  Big Daddy   drama  1999         6.4
# 218  219                                      Se7en   drama  1995         8.6
# 219  220                                      Seven   drama  1979         6.1
#
# [220 rows x 5 columns]

# %% [markdown]
# Vamos a aprender sobre estas peliculas, traiga las primeras 5 de su DataFrame

# %%
df.head()
# Out:
#    id                                       name   genre  year imdb_rating
# 0   1                                     Avatar  action  2009         7.9
# 1   2                             Jurassic World  action  2015         7.3
# 2   3                               The Avengers  action  2012         8.1
# 3   4                            The Dark Knight  action  2008         9.0
# 4   5  Star Wars: Episode I - The Phantom Menace  action  1999         6.6

# %% [markdown]
# Que hay exactamente en este DataFrame? Como averiguamos mas sobre el?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220 entries, 0 to 219
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           220 non-null    int64
#  1   name         220 non-null    object
#  2   genre        220 non-null    object
#  3   year         220 non-null    int64
#  4   imdb_rating  220 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 8.7+ KB
